# %%
# 사용 모듈 import
import pymysql
import csv
import pandas as pd
import numpy as np
import config

import folium

# %%
# 데이터베이스 연동

db = pymysql.connect(
    host=config.DATABASE_CONFIG['host'], 
	port=3306, 
	user=config.DATABASE_CONFIG['user'],
	passwd=config.DATABASE_CONFIG['password'],
	db=config.DATABASE_CONFIG['db'],charset='utf8',autocommit=True
)

cursor = db.cursor()

# %%
# 테이블 생성(시설 테이블)

cursor.execute("""CREATE TABLE mapdb.facilities (
  num int AUTO_INCREMENT NOT NULL,
  name VARCHAR(45) NOT NULL,
  phone varchar(15) NULL,
  address VARCHAR(110) NOT NULL,
  longitude FLOAT(13, 10) NULL,
  latitude FLOAT(12, 10) NULL,
  big_address VARCHAR(45) NOT NULL,
  PRIMARY KEY (num));""")

# %%
# 데이터 셋 가공(시설 정보), 시설정보 테이블에 저장
# name, address 경도, 위도, 넓은 범위 주소

facilities = []

sql = "INSERT INTO facilities (name, phone, address, latitude, longitude, big_address) VALUES (%s, %s, %s, %s, %s, %s)"

# csv파일로부터 데이터셋 데이터베이스에 저장
with open('facilities.csv', 'r') as fileRead:
    reader = csv.reader(fileRead)
    i = 0
    for line in reader:
        facilities.append(line)
        facilities[i][2] = facilities[i][2][4:]
        temparr = facilities[i][2].split(" ")
        tempadd = temparr[0] + " " + temparr[1]
        facilities[i].append(tempadd)
        if facilities[i][3] == "":
            facilities[i][3] = facilities[i][4] = 0
        if i != 0 :
            cursor.execute(sql, (facilities[i][0], facilities[i][1], facilities[i][2], facilities[i][3], facilities[i][4], facilities[i][5]))
        i += 1
    

cursor.close()

# %%
# 테이블 생성(지역 테이블)

cursor.execute("""
CREATE TABLE mapdb.sectors (
    big_address VARCHAR(45) NOT NULL PRIMARY KEY,
    longitude FLOAT(13, 10) NULL,
    latitude FLOAT(12, 10) NULL);
""")
# Out:
# 3

# %%
# 테이블 생성(예방접종 예약)

cursor.execute("""
CREATE TABLE mapdb.reservations(
    name VARCHAR(10) NOT NULL,
    date DATE NOT NULL,
    hospital VARCHAR(45) NOT NULL,
    phone VARCHAR(15) NULL,
    address VARCHAR(110) NOT NULL,
    fasnum INT NOT NULL,
    PRIMARY KEY (name, fasnum),
    CONSTRAINT reserve
     FOREIGN KEY (fasnum)
     REFERENCES mapdb.facilities(num) 
     ON UPDATE CASCADE
     ON DELETE CASCADE);
""")
# Out:
# 0

# %%
# 테스트

cursor.execute("describe sectors;")
suc = cursor.fetchall()
print(suc)
# Out:
# (('big_address', 'varchar(45)', 'NO', 'PRI', None, ''), ('longitude', 'float(13,10)', 'YES', '', None, ''), ('latitude', 'float(12,10)', 'YES', '', None, ''))

# %%
# 데이터 셋 가공(지역 정보)

cursor.execute("""
SELECT big_address, AVG(longitude) AS longitude, AVG(latitude) as latitude 
FROM facilities
WHERE longitude != 0 AND latitude != 0
GROUP BY big_address;""")

sector = cursor.fetchall()

print(sector[0])
# Out:
# ('수원시 장안구', 127.00037107362851, 37.29908844664857)

# %%
# 지역정보 테이블에 저장

sql = "INSERT INTO sectors (big_address,longitude, latitude) VALUES (%s, %s, %s)"

for sec in sector:
    cursor.execute(sql, (sec[0], sec[1], sec[2]))

# %%
# 테이블 참조를 위해 데이터 삭제, 데이터베이스 수정 후 재입력

# 삭제
cursor.execute("truncate facilities;")

# 외래키 설정
cursor.execute("""
ALTER TABLE facilities
ADD CONSTRAINT search
FOREIGN KEY (big_address)
REFERENCES sectors(big_address);
""")

# 앞서 데이터 입력 재실행

# %%
# 시설 릴레이션의 외래키 설정

cursor.execute("""ALTER TABLE facilities
                  ADD CONSTRAINT search
                  FOREIGN KEY (big_address)
                  REFERENCES sectors (big_address);""")

# %%
# 검색의 편의성을 위해 시설 릴레이션의 외래키, 시설명에 인덱스 추가

cursor.execute("ALTER TABLE facilities ADD INDEX addressSearch(big_address);")
cursor.execute("ALTER TABLE facilities ADD INDEX sameNameFacilities(name);")
# Out:
# 0

# %%
# 지도 탐색 함수 설계


# 지역검색 함수
def sectorSearch():
    sql = "SELECT * FROM facilities WHERE big_address=%s;"
    sec = input("지역 입력 : ")
    cursor.execute(sql, sec)
    result = cursor.fetchall() # 데이터베이스로 부터 불러온 데이터 저장
    data = []
    data = createDataframe(result)
    if len(data) == 0:
        print("지역 정보가 없습니다.")
        return
    df = pd.DataFrame(data)
    df = df.astype({'위도' : np.float,'경도' : np.float})
    return (printMap(df, sec), df)
    
    
# 검색한 지역에 대한 시설 데이터를 가공하는 함수
# 0번호, 1시설 명, 2전화번호, 3주소, 4경도, 5위도, 6지역
def createDataframe(result):
    data = []
    for facil in result:
        temp = {"시설 번호": facil[0], "시설 명": facil[1], "전화번호": facil[2], "도로명 주소": facil[3], "경도": facil[4], "위도": facil[5]}
        data.append(temp)
    return data
    
    
# 입력값을 바탕으로 지도를 출력하는 함수
def printMap(df, sec):
    sql = "SELECT longitude, latitude FROM sectors WHERE big_address=%s"
    cursor.execute(sql, sec)
    result = cursor.fetchone()
    map = folium.Map(location=[result[1] ,result[0]],zoom_start=14)
    for i in range(0, df.shape[0]) :
        folium.Circle([df['위도'][i] ,df['경도'][i]],popup = df['시설 명'][i],
                       radius = 15, color = "#00f",fill_color = '#fff').add_to(map)
    map.save('result.html')
    return map
    
    
(map, df) = sectorSearch()
map
# Out:
# 지역 입력 : 수원시 영통구
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_14e18daf7b304566bfe08c3d94662989%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_14e18daf7b304566bfe08c3d94662989%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_14e18daf7b304566bfe08c3d94662989%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_14e18daf7b304566bfe08c3d94662989%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.2655334473%2C%20127.0562896729%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
df
# Out:
#     시설 번호            시설 명          전화번호  \
# 0      20         365내과의원  031-233-2878
# 1      37  365아이랑소아청소년과의원  031-273-0203
# 2      55         365힐링의원  031-203-3650
# 3     162      고려웰가정의학과의원  031-217-8871
# 4     216      광교365메디컬의원  031-213-3655
# ..    ...             ...           ...
# 94   3936       허브이비인후과의원  031-546-2848
# 95   3951       현대가정의학과의원  031-202-7969
# 96   4028     홍진희소아청소년과의원  031-273-7582
# 97   4051         황인섭내과의원  031-214-8300
# 98   4064           휴내과의원  031-213-5484
#
#                                                도로명 주소          경도         위도
# 0          수원시 영통구 봉영로 1569, (영통동, 뉴월드프라자 402,403호)    127.071022  37.252064
# 1          수원시 영통구 중부대로 604, (영통동, 수원영통리슈빌스카이오피스텔) 1층  127.081390  37.267296
# 2                         수원시 영통구 영통로 151, (망포동)  2층   127.055267  37.240944
# 3                 수원시 영통구 대학로 109, (이의동, 골드클래스5) 302호  127.047165  37.305096
# 4       수원시 영통구 광교중앙로 170, (하동) 광교 효성해링턴 타워 313호,314호  127.060699  37.288124
# ..                                                ...         ...        ...
# 94  수원시 영통구 매영로310번길 87, (영통동)  동보.신명아파트 2층 208호 2...  127.064087  37.250664
# 95       수원시 영통구 봉영로1770번길 21, (영통동, 신명.한국아파트)  216호   127.083084  37.267418
# 96                         수원시 영통구 영통로214번길 9, (영통동)   127.057640  37.246578
# 97                 수원시 영통구 매영로 85, (매탄동, 성일코아빌딩) 401호  127.052094  37.268158
# 98  수원시 영통구 센트럴타운로 114-8, (이의동) 농업회사법인 (주) 농우바이오 1...  127.050354  37.293690
#
# [99 rows x 6 columns]

# %%
# 예방접종 시설 검색 함수 설계

def facilitySearch():
    sql = "SELECT * FROM facilities WHERE name=%s;"
    sec = input("시설명 입력 : ")
    cursor.execute(sql, sec)
    result = cursor.fetchall() # 데이터베이스로 부터 불러온 데이터 저장
    data = []
    data = createDataframe(result)
    if len(data) == 0:
        print("지역 정보가 없습니다.")
        return
    df = pd.DataFrame(data)
    print(df)
    num = input("조회하고자 하는 시설의 번호를 입력해주세요 : ")
    df = df.astype({'위도' : np.float,'경도' : np.float})
    return (printFacilityMap(df, num), df)


def printFacilityMap(df, num):
    sql = "SELECT longitude, latitude, name FROM facilities WHERE num=%s"
    cursor.execute(sql, num)
    result = cursor.fetchone()
    map = folium.Map(location=[result[1] ,result[0]],zoom_start=17)
    folium.Circle([result[1] ,result[0]], popup = result[2],
                   radius = 15, color = "#00f", fill_color = '#fff').add_to(map)
    for i in range(0, df.shape[0]) :
        if(df['시설 번호'][i] == str(num)) :
            folium.Circle([df['위도'][i] ,df['경도'][i]],popup = df['시설 명'][i],
                           radius = 15, color = "#00f",fill_color = '#fff').add_to(map)
    map.save('result2.html')
    return map
        
        
(map, df) = facilitySearch()
map
# Out:
# 시설명 입력 : 강내과의원
#    시설 번호   시설 명          전화번호                             도로명 주소          경도  \
# 0     99  강내과의원  02-2611-3777        광명시 오리로 941, (광명동, 명성빌딩) 3층  126.858284
# 1    100  강내과의원  031-203-7585       화성시 영통로61번길 6, (반월동, 제일프라자)   127.061150
# 2    101  강내과의원  031-445-7585  안양시 동안구 관악대로 72, (비산동, 동화빌딩)  3층   126.932327
# 3    102  강내과의원  031-675-2255                안성시 금산길 8, (연지동) 2층  127.270920
# 4    103  강내과의원  031-944-4415         파주시 중앙로 303, (금촌동) 재성빌딩 2층  126.775368
# 5    104  강내과의원  032-654-8275               부천시 장말로 202, (상동) 2층  126.764320
#
#           위도
# 0  37.478020
# 1  37.235497
# 2  37.397640
# 3  37.011303
# 4  37.762661
# 5  37.492687
# 조회하고자 하는 시설의 번호를 입력해주세요 : 100
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9fc7ba41fd5847149fb4ea2e30d2ec9a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9fc7ba41fd5847149fb4ea2e30d2ec9a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9fc7ba41fd5847149fb4ea2e30d2ec9a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9fc7ba41fd5847149fb4ea2e30d2ec9a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.235496521%2C%20127.0611495972%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# 예방접종 예약 함수 설계

def reservation():
    name = input("접종자 명을 입력 : ")
    facilNum = input("예방접종할 시설의 시설 번호를 입력 : ")
    date = input("접종 날짜를 입력(YY-MM-DD) : ")
    sql = "SELECT * FROM facilities WHERE num=%s;"
    cursor.execute(sql, facilNum)
    facilInfo = cursor.fetchone()
    if (not facilInfo):
        print("없는 시설 번호 입니다.")
        return
    sql2 = "INSERT INTO reservations (name, date, hospital, phone, address, fasnum) VALUES (%s, %s, %s, %s, %s, %s)"    
    cursor.execute(sql2, (name, date, facilInfo[1], facilInfo[2], facilInfo[3], facilInfo[0]))
    print("예약되었습니다.")
    
reservation()
# Out:
# 접종자 명을 입력 : 홍길동
# 예방접종할 시설의 시설 번호를 입력 : 11
# 접종 날짜를 입력(YY-MM-DD) : 211231
# 예약되었습니다.

# %%
# 예방접종 시설 삭제 함수 설계

def deleteFacility():
    facilNum = input("삭제할 시설 번호를 입력 : ")
    sql1 = "SELECT name FROM reservations WHERE fasnum=%s;"
    cursor.execute(sql1, facilNum)
    reserRequest = cursor.fetchall()
    if (reserRequest):
        print("해당 시설의 백신접종 예약자가 존재하므로, 연락 및 조치 후 삭제하실 수 있습니다.")
        print("예약자 명단 : ", reserRequest)
        return
    else:
        sql2 = "DELETE FROM facilities WHERE num=%s;"
        cursor.execute(sql2, facilNum)
        print("정상 삭제되었습니다.")
    
deleteFacility()
# Out:
# 삭제할 시설 번호를 입력 : 32
# 해당 시설의 백신접종 예약자가 존재하므로, 연락 및 조치 후 삭제하실 수 있습니다.
# 예약자 명단 :  (('김철수',), ('홍길동',))

# %%
cursor.close()
